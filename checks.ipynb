# %%
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.distributions.empirical_distribution import ECDF
import plotly.express as px
from enum import Enum

from checks import ROLLS

SZ = 10000000

rolls = ROLLS["D20"]()
print(rolls)

ecdf = ECDF(rolls)

vals = ecdf(19) - ecdf(5)
print(vals)
# Out:
# [ 1 15  6 ... 12 11  4]
# 0.6919
